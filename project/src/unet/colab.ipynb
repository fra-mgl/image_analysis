# %%
# install dependencies
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import shutil

shutil.rmtree('/content/image_analysis')

# %%
# clone repo
# !git clone -b Chiara_colab --single-branch https://github.com/fra-mgl/image_analysis.git
# %cd image_analysis/project/u-net
# Out:
# Cloning into 'image_analysis'...
# remote: Enumerating objects: 262, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 262 (delta 24), reused 22 (delta 21), pack-reused 228 (from 1)
# Receiving objects: 100% (262/262), 86.84 MiB | 25.99 MiB/s, done.
# Resolving deltas: 100% (102/102), done.
# /content/image_analysis/project/u-net/image_analysis/project/u-net

# %%
import shutil

shutil.rmtree('/content/image_analysis/project/u-net/VOCdevkit')

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# define paths for dataset and output
output_dir = "/content/drive/MyDrive/IAPR_drive/model_results"
data_folder = "/content/drive/MyDrive/IAPR_drive/datasets/VOCdevkit"

# %%
# !nvidia-smi
# Out:
# Fri May  9 13:40:23 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# training
from train_colab import train,  TrainingParams

params = TrainingParams(
        data_folder = data_folder,
        model_folder = output_dir,
        epoch_number = 30, #CHECKKKKKK
        saving_interval = 5,
        shuffle = True
    )


train(params)
# OPTIONAL: Move a model file to Google Drive if generated
# Example: If your script saves 'model.pt' in current dir
# if os.path.exists("model.pt"):
#     !cp model.pt {output_dir}/
# Out:
# Defining transform...
# Loading dataset...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-571705d40fd6> in <cell line: 0>()
#      11
#      12
# ---> 13 train(params)
#      14 # OPTIONAL: Move a model file to Google Drive if generated
#      15 # Example: If your script saves 'model.pt' in current dir
#
# /content/image_analysis/project/u-net/train_colab.py in train(params)
#      82     #2. Load dataset
#      83     print("Loading dataset...")
# ---> 84     dataset = datasets.VOCSegmentation(
#      85         params.data_folder,
#      86         year="2007",
#
# /usr/local/lib/python3.11/dist-packages/torchvision/datasets/voc.py in __init__(self, root, year, image_set, download, transform, target_transform, transforms)
#      99
#     100         if not os.path.isdir(voc_root):
# --> 101             raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#     102
#     103         splits_dir = os.path.join(voc_root, "ImageSets", self._SPLITS_DIR)
#
# RuntimeError: Dataset not found or corrupted. You can use download=True to download it
