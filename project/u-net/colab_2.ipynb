# %%
# install dependencies
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
import shutil

shutil.rmtree('/content/image_analysis')

# %%
# clone repo
# !git clone -b Chiara_colab --single-branch https://github.com/fra-mgl/image_analysis.git
# %cd image_analysis/project/u-net
# Out:
# Cloning into 'image_analysis'...
# remote: Enumerating objects: 437, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (127/127), done.
# remote: Total 437 (delta 144), reused 139 (delta 82), pack-reused 228 (from 1)
# Receiving objects: 100% (437/437), 87.00 MiB | 12.64 MiB/s, done.
# Resolving deltas: 100% (222/222), done.
# /content/image_analysis/project/u-net

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
# define paths for dataset and output
output_dir = "/content/drive/MyDrive/IAPR_drive/model_results/"
data_folder = "/content/drive/MyDrive/IAPR_drive/datasets_2/"

# %%
# !nvidia-smi
# Out:
# Fri May  9 13:40:23 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# training
from train_colab_2 import train,  TrainingParams
import numpy as np

params = TrainingParams(
        data_folder = data_folder,
        model_folder = output_dir,
        epoch_number = 120, #CHECKKKKKK
        saving_interval = 5,
        bilateral_parameters = np.array([7, 30, 30]),
        shuffle = True,
        pretrained_weights= "/content/drive/MyDrive/IAPR_drive/model_results/eli/unet_voc_best.pt",
        previous_epochs=0

    )


train(params)
# OPTIONAL: Move a model file to Google Drive if generated
# Example: If your script saves 'model.pt' in current dir
# if os.path.exists("model.pt"):
#     !cp model.pt {output_dir}/
# Out:
# Defining transform...
# Loading dataset...
# Class Weights: tensor([0.0003, 0.0768, 0.0702, 0.0602, 0.0638, 0.1284, 0.1187, 0.1263, 0.0656,
#         0.0576, 0.0457, 0.0658, 0.0617, 0.0589], device='cuda:0')
# Defining model...
# Total parameters: 7703822
# 🔄 Loading pre-trained weights from /content/drive/MyDrive/IAPR_drive/model_results/eli/unet_voc_best.pt - current epoch 0
#
# 🔁 Epoch 1/120
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3887efb15eeb> in <cell line: 0>()
#      16
#      17
# ---> 18 train(params)
#      19 # OPTIONAL: Move a model file to Google Drive if generated
#      20 # Example: If your script saves 'model.pt' in current dir
#
# /content/image_analysis/project/u-net/train_colab_2.py in train(params)
#     207             loss = 0.5 * loss_ce + 0.5 * loss_dice
#     208             loss.backward()
# ...
